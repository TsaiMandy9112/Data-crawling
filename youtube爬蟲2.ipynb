# %%
import requests
import json
import sqlite3
import pandas as pd

res=requests.get('https://www.youtube.com/api/stats/ads?ver=2&ns=1&event=2&device=1&content_v=-aYRCoY-_kA&el=detailpage&ei=U5dyY_X4Na2YvcAPkICa8AI&devicever=2.20221112.07.00&bti=9477942&format=15_2_4&break_type=1&conn=0&cpn=wP_A3nNuS8T2jwy9&lact=1348&m_pos=0&mt=8000&p_h=240&p_w=426&rwt=[RWT]&sdkv=h.3.0.0&slot_pos=0&slot_len=2&vis=0&vol=75&wt=1668454229680&ad_cpn=i5ei0lKPTtSudPmw&ad_id=,585470843680&ad_len=6000&ad_mt=22&ad_sys=YT:AdSense-Viral,AdSense-Viral&ad_v=3nDptQLiq-M&aqi=U5dyY_KBOozGgAPw5KqYBA&ad_rmp=1&sli=1&slfs=1&loginael=1')
data=res.json()

'''
url = "https://www.youtube.com/api/stats/ads?ver=2&ns=1&event=2&device=1&content_v=-aYRCoY-_kA&el=detailpage&ei=U5dyY_X4Na2YvcAPkICa8AI&devicever=2.20221112.07.00&bti=9477942&format=15_2_4&break_type=1&conn=0&cpn=wP_A3nNuS8T2jwy9&lact=1348&m_pos=0&mt=8000&p_h=240&p_w=426&rwt=[RWT]&sdkv=h.3.0.0&slot_pos=0&slot_len=2&vis=0&vol=75&wt=1668454229680&ad_cpn=i5ei0lKPTtSudPmw&ad_id=,585470843680&ad_len=6000&ad_mt=22&ad_sys=YT:AdSense-Viral,AdSense-Viral&ad_v=3nDptQLiq-M&aqi=U5dyY_KBOozGgAPw5KqYBA&ad_rmp=1&sli=1&slfs=1&loginael=1"
text = requests.get(url)
'''
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/urllib3/connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# /opt/anaconda3/lib/python3.9/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# /opt/anaconda3/lib/python3.9/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# ...

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/2p/bfbv31p50qg35jbmb1fczxq80000gn/T/ipykernel_23395/391604064.py in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
'''pretext = ")]}\'"
text = text.replace(pretext,' ')
response_data = res.json()
'''
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/2p/bfbv31p50qg35jbmb1fczxq80000gn/T/ipykernel_23395/3469709886.py in <module>
#       1 pretext = ")]}\'"
# ----> 2 text = text.replace(pretext,' ')
#       3 response_data = res.json()
#
# AttributeError: 'Response' object has no attribute 'replace'

# %%
'''import requests
from bs4 import BeautifulSoup

res = requests.get("https://www.youtube.com/watch?v=-aYRCoY-_kA&t=8s")

soup = BeautifulSoup(res.text, 'html.parser')

# %%
'''soup
# Out:
# <!DOCTYPE html>
# <html darker-dark-theme="" lang="zh-Hant-TW" style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" system-icons="" typography="" typography-spacing=""><head><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="AlgsH67ctYlMR3JYAxEnGfvsoFo41AMqAg6wRHHXOpWAfD54ZCfTPBclxnFT4Gc8IUX4pq6Xfo0esDuOt+WH3wIAAABteyJvcmlnaW4iOiJodHRwczovL3lvdXR1YmUuY29tOjQ0MyIsImZlYXR1cmUiOiJQcml2YWN5U2FuZGJveEFkc0FQSXMiLCJleHBpcnkiOjE2ODA2NTI3OTksImlzU3ViZG9tYWluIjp0cnVlfQ==" http-equiv="origin-trial"/><script nonce="crzUzaIUJir5P4_YVm_G4A">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else for(var k in a[0])ytcfg.d()[k]=a[0][k]}};
# ...

# %%
'''clean = soup.select('span')

# %%
'''clean
# Out:
# [<span itemprop="author" itemscope="" itemtype="http://schema.org/Person"><link href="http://www.youtube.com/channel/UCAvlsm2Zjqvh12Od0yWvoPQ" itemprop="url"/><link content="rice &amp; shine" itemprop="name"/></span>,
#  <span itemprop="thumbnail" itemscope="" itemtype="http://schema.org/ImageObject"><link href="https://i.ytimg.com/vi/-aYRCoY-_kA/maxresdefault.jpg" itemprop="url"/><meta content="1280" itemprop="width"/><meta content="720" itemprop="height"/></span>,
#  <span itemprop="publication" itemscope="" itemtype="http://schema.org/BroadcastEvent"><meta content="True" itemprop="isLiveBroadcast"/><meta content="2021-07-29T16:37:07+00:00" itemprop="startDate"/><meta content="2021-07-29T16:48:31+00:00" itemprop="endDate"/></span>,
#  <span id="country-code"></span>]

# %%
'''import requests
import json
from jsonpath import jsonpath

x=1

for offset in range(20):  #控制換頁迴圈
    
    url = "https://www.gstatic.com/external_hosted/lottie/lottie_light.js"
    res = requests.get(url)
    clean_needed = res.text
    
    clean = clean_needed.replace('','').replace('','')
    Json_Data = json.loads(clean)
    
    if len(Json_Data) == 870:
        for times in range(19):
            book_name = jsonpath(Json_Data[times], '$.Nick')
            book_price = jsonpath(Json_Data[times], '$.Price.P')
            print(book_name + book_price)
    else:
        for times in range(20):
            book_name = jsonpath(Json_Data[times], '$.Nick')
            book_price = jsonpath(Json_Data[times], '$.Price.P')
            print(book_name + book_price)
    
    x += 20   # 等同於 x = x + 20
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /var/folders/2p/bfbv31p50qg35jbmb1fczxq80000gn/T/ipykernel_23395/549062952.py in <module>
#      12
#      13     clean = clean_needed.replace('','').replace('','')
# ---> 14     Json_Data = json.loads(clean)
#      15
#      16     if len(Json_Data) == 870:
#
# /opt/anaconda3/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /opt/anaconda3/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# ...
